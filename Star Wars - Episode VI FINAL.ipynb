# %%
#########
# Intro #
#########

import sys

def start():
    print("A long time ago in a galaxy far, far away....")
    input("\n<Press enter to start>\n")
    #Logo
    print("""
             ____  _              __        __           
            / ___|| |_ __ _ _ __  \ \      / /_ _ _ __ ___ 
            \___ \| __/ _` | '__|  \ \ /\ / / _` | '__/ __|
             ___) | || (_| | |      \ V  V / (_| | |  \__ \ 
            |____/ \__\__,_|_|       \_/\_/ \__,_|_|  |___/                                            
    """)
    input()
    
    #Opening crawl (Using a loop to make it appear slowly)
    
    import time
    for i in range(1):
        print("""
                Luke Skywalker has returned to
                his home planet of Tatooine in
                an attempt to rescue his
                friend Han Solo from the
                clutches of the vile gangster
                Jabba the Hutt.
                """)
        time.sleep(3)
        
        
    for i in range(1):
        print("""
                Little does Luke know that the 
                GALACTIC EMPIRE has secretly
                begun construction on a new
                armored space station even
                more powerful than the first
                dreaded Death Star.
                """)
        time.sleep(3)
        
        
        
    for i in range(1):
        print("""
                When completed, this ultimate
                weapon will spell certain doom
                for the small band of rebels
                struggling to restore freedom
                to the galaxy...
                """)
            
        time.sleep(5)

        stage_1()
    

    


#######################
#Fighting the soldiers#
#######################


    
def fail_1():
    print("You've been captured again.")
    
    input("\n<Press enter to continue>\n")
    
    stage_1()

def stage_1():
    
    input("\n<Press enter to continue>\n")
    
    # Defining the characters

    character1 = "Luke"
    character2 = "Han Solo"
    character3 = "Princess Leia"
    character4 = "Lando Calrissian"
    character5 = "C-3PO"
    character6 = "Chewbacca"
    character7 = "Darth Vader"
    character8 = "The Emperaror"
    
    
   # Challenge 1 - Randomly choosing the number of guards

    import random
    guards = random.randint(8, 20)
    Luke_Force = 10
    Han_Force = 8
    
    
    #Storyline
    print(f"""
    {character1} and {character2} end up both being captured and sentenced to 
    death by feeding them to the Sarlacc. But Luke frees himself and so does
    {character2}! They now have to fight {guards} Jabba's Guards.

    """)
    
    
    #Conditions to win the guards
     
              
    if 2 * guards < Luke_Force + Han_Force:
        print("""
              
           ___________.__             ___________                          .__                   
\__    ___/|  |__   ____   \_   _____/__________   ____  ____   |__| ______           
  |    |   |  |  \_/ __ \   |    __)/  _ \_  __ \_/ ___\/ __ \  |  |/  ___/           
  |    |   |   Y  \  ___/   |     \(  <_> )  | \/\  \__\  ___/  |  |\___ \            
  |____|   |___|  /\___  >  \___  / \____/|__|    \___  >___  > |__/____  >           
                \/     \/       \/                    \/    \/          \/            
          __                                 .__         .____           __           
  _______/  |________  ____   ____    ____   |__| ____   |    |    __ __|  | __ ____  
 ___(/\, __\_, __, \/, _, \, /, \, /, ___\, |, |/, \, |, |, |, |, \, |/, //, __, \)
 \___ \  |  |  |  | \(  <_> )   |  \/ /_/  > |  |   |  \ |    |___|  |  /    <\  ___/ 
____(>, |__|, |__|, \____/|___|, /\___, /, |__|___|, /, |_______, \____/|__|_, \\___, >)
     \/                          \//_____/           \/          \/          \/    \/    
              
              
              
              
     You defeated the guards and destroyed Jabba's sail barge.""")
        
        input()
        stage_2()
              
              

    elif guards < Luke_Force + Han_Force:
        print("""
        You defeated the guards and safely escaped.""")
        stage_2()

    elif guards == Luke_Force + Han_Force:
        print("""
        You safely escaped.""")
        stage_2()

    elif guards > Luke_Force + Han_Force:
        fail_1()

    else:
        print("""
        Something went wrong. Likely we've been persuaded by the Dark Side.
        
        """)
      

    
    
    
    
    
###################
# Yoda's Question #
###################

def stage_2():

    input("\n<Press enter to continue>\n")
    
    #Storyline 

    print("""

    Luke returns to Dagobah where he finds ou that Yoda is dying. But moments 
    before his death he makes an important revelation.

    """)

    # Challenge 2
    guess = input("""
    Which of these was Yoda's revelation.
    
    (Please type a, b, or b.)
    
        a. Darth Vader is Luke's father.
        b. Leia's is Luke's sister.
        c. He won't be able to defeat the Empire due to the fact he didn't 
        completed his training.

    """)

    # Conditions
    str3 = 'a'
    str4 = 'b'
    str5 = 'c'
    
    if guess == str3 or str3.casefold in guess :
        print("Clear your mind of questions, young aprentice.")
        stage_3()

    elif guess == str4 or str4.casefold in guess:
        print("Already know you, that wich you need, young aprentice.")
        stage_3()

    elif guess == str5 or str5.casefold in guess:
        print("Do or do not. There is no try, young aprentice.")
        stage_3()

    else:

        print("""
        
        Something went wrong. Likely we've been persuaded by the Dark Side.""")
        
        stage_1()
        


        
        

###################       
# Ewook judgement #
###################


def fail_3():
    print("You proof not to be worth the Ewook's tribe trust.")
    
    game = input("""
        Would you like to play again?
        """)

    str1 = ("Yes")
    str2 = ("No")

    if game == str1 or str1.lower() in game :
            start()

    elif game == str2 or str2.lower() in game :
            sys.exit()



def stage_3():
    
    input("\n<Press enter to continue>\n")
    
    #Storyline
    
    print("""

    The Rebell Alliance finds out that the First Order is constructing a new 
    Death Star. Luke and his friends go on a new mission to destroy the shield
    generator so that the Rebell Aliance can attack it. 

    Nevertheless, our heroes are captured by a Ewook's tribe. In order to gain 
    they're trust they have to make proof of whom they are. 

    """)
    
    #Randomly choosing either dark or light#
    
    import random
    Force = ['light', 'dark']
    Force_1 = random.choice(Force)
    
    if Force_1 == 'light':
        print(f"You prooved to have", {Force_1}, "on you.")
        stage_4()
    
    elif Force_1 == 'dark':
        print(f"You prooved to have", {Force_1}, "on you.")
        print("The Dark Side of Force persuade you. You loose.")
        fail_2()
    
    else:
        print("Something went wrong. Likely we've been persuaded by the Dark Side.")
        fail_3()
         


    
    

############    
# The Duel #
############


def fail_4():
    print(f"""
Vader defeated you. The Dark Side arose and the Empire conquered
the galaxy.""")
    
    game = input("""
        Would you like to play again?
        """)

    str1 = ("Yes")
    str2 = ("No")

    if game == str1 or str1.lower() in game :
            start()

    elif game == str2 or str2.lower() in game :
            sys.exit()

    
    

def stage_4():
    
    input("\n<Press enter to continue>\n")
    
    print("""
    

                           .-.
                          |_:_|
                         /(_Y_)\
    .                   ( \/M\/ )
     '.               _.'-/'-'\-'._
       ':           _/.--'[[[[]'--.\_
         ':        /_'  : |::"| :  '.\
           ':     //   ./ |oUU| \.'  :\
             ':  _:'..' \_|___|_/ :   :|
               ':.  .'  |_[___]_|  :.':\
                [::\ |  :  | |  :   ; : \
                 '-'   \/'.| |.' \  .;.' |
                 |\_    \  '-'   :       |
                 |  \    \ .:    :   |   |
                 |   \    | '.   :    \  |
                 /       \   :. .;       |
                /     |   |  :__/     :  \\
               |  |   |    \:   | \   |   ||
              /    \  : :  |:   /  |__|   /|
             |     : : :_/_|  /'._\  '--|_\
              /___.-/_|-'   \  \
                             '-'
    The moment has come. Luke surrended himself to the Empiral troops and he's
brought to the Emperaror. The Emperaror reveals the Death Star is fully 
operational and the Rebels are about to fall into a trap. Luke engages 
Vader in a lightsaber duel. 


In order to win this duel you have to get inside's Vader mind and guess which
number is he thinking of (from 1 to 6). Type down your guess. \n
    
    """)
    
    # Fighting Darth Vader by guessing the right number from 1 to 6

    import random

    number = random.randint(1,6)
    guesses = 3

    while guesses >=0:
        choice = (input("> "))

        if choice == str(number):
            print(f"""
            
Luke defeated Vader. The the Emperaror asks Luke to kill Vader and take his 
place. Luke refuses. The Emperaror tries to kill Luke but Vader, unwilling to
see his son die, throws the Emperaror down a reactor. However, in the process
Vader is mortally electrocuted.
            
            """)
            stage_5()
        
        if guesses==0:
            fail_4()

        elif choice != str(number):
            print('Vader hitted Luke.')
            guesses -= 1

        else:
            print(""""
            Something went wrong. Likely we've been persuaded by the Dark 
            Side.""")
        
        

#############        
# Game-Over #
#############

def stage_5():
    
    input("\n<Press enter to continue>\n")

    print(f"""

As the battle between the Rebel Aliance and the Imperial fleets 
continues, the strike team lead by Han Solo, destroys the shield
generator. Shortly, the Rebel space ships manage to destroy the 
Death star.it.The Rebels celebrate their victory over the Empire. 
Luke smiles as hesees the spirit of Vader, Yoda and Obi-Wan.

May the Force be with you ✌🏼

                        ____
                     _.' :  `._
                 .-.'`.  ;   .'`.-.
        __      / : ___\ ;  /___ ; \      __
      ,'_ ""--.:__;".-.";: :".-.":__;.--"" _`,
      :' `.t""--.. '<@.`;_  ',@>` ..--""j.' `;
           `:-.._J '-.-'L__ `-- ' L_..-;'
             "-.__ ;  .-"  "-.  : __.-"
                 L ' /.------.\ ' J
                  "-.   "--"   .-"
                 __.l"-:_JL_;-";.__
              .-j/'.;  ;  / .'\"-.                                        
            .' /:`. "-.:     .-" .';  `.
         .-"  / ;  "-. "-..-" .-"  :    "-.
      .+"-.  : :      "-.__.-"      ;-._   \
      ; \  `.; ;                    : : "+. ;
      :  ;   ; ;                    : ;  : \:
     : `."-; ;  ;                  :  ;   ,/;
      ;    -: ;  :                ;  : .-"'  :
      :\     \  : ;             : \.-"      :
       ;`.    \  ; :            ;.'_..--  / ;
       :  "-.  "-:  ;          :/."      .'  :
         \       .-`.\        /t-""  ":-+.   :
          `.  .-"    `l    __/ /`. :  ; ; \  ;
            \   .-" .-"-.-"  .' .'j \  /   ;/
             \ / .-"   /.     .'.' ;_:'    ;
              :-""-.`./-.'     /    `.___.'
                    \ `t  ._  /  bug :F_P:
                     "-.t-._:'

""")
    
    game = input("""
    Would you like to play again?
    """)
    
    if game == 'yes'.casefold in game :
        start()
    
    elif game == 'no'.casefold in game :
        sys.exit()

# %%
game = input("""
    Would you like to play again?
    """)
    
st3 = 'yes'
st4 = 'no'
    
if game == st3.casefold() in game :
    print('Kiko')
    
elif game == st4.casefold() in game :
    print('Joao')
